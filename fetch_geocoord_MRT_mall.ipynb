# %%
"""
Retrieve and output geocoordinates of various MRT stations and shopping malls in Singapore
for subsequent use
"""

# %%
# Import libraries
import math
import json
import requests
import pandas as pd
import numpy as np
import os

# %%
# Set display options
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 500)

# %%
# Change directories
os.chdir(r'/Users/sawleen/Documents/Leen/MTech EBAC NUS ISS/Sem 1 2021/Practice Module/Data')

# %%
############ Get coordinates of MRT stations ############

# %%
# Initialize empty dataframe to store details
mrt_location=pd.DataFrame([],columns=['MRT','latitude','longitude'])

# Get list of MRT to search for
mrt_data=pd.read_csv('train-station-chinese-names.csv') #Downloaded from data.gov.sg
mrt_data.head()
# Out:
#   stn_code mrt_station_english mrt_station_chinese  mrt_line_english  \
# 0      NS1         Jurong East                 裕廊东  North South Line
# 1      NS2         Bukit Batok                武吉巴督  North South Line
# 2      NS3        Bukit Gombak                武吉甘柏  North South Line
# 3      NS4       Choa Chu Kang                 蔡厝港  North South Line
# 4      NS5             Yew Tee                  油池  North South Line
#
#   mrt_line_chinese
# 0              南北线
# 1              南北线
# 2              南北线
# 3              南北线
# 4              南北线

# %%
# Eyeball to see if data is complete
print('Number of MRT stations downloaded: {}'.format(len(mrt_data)))
print(mrt_data.mrt_station_english.unique())
# Out:
# Number of MRT stations downloaded: 184
# ['Jurong East' 'Bukit Batok' 'Bukit Gombak' 'Choa Chu Kang' 'Yew Tee'
#  'Kranji' 'Marsiling' 'Woodlands' 'Admiralty' 'Sembawang' 'Yishun'
#  'Khatib' 'Yio Chu Kang' 'Ang Mo Kio' 'Bishan' 'Braddell' 'Toa Payoh'
#  'Novena' 'Newton' 'Orchard' 'Somerset' 'Dhoby Ghaut' 'City Hall'
#  'Raffles Place' 'Marina Bay' 'Marina South Pier' 'Pasir Ris' 'Tampines'
#  'Simei' 'Tanah Merah' 'Bedok' 'Kembangan' 'Eunos' 'Paya Lebar' 'Aljunied'
#  'Kallang' 'Lavender' 'Bugis' 'Tanjong Pagar' 'Outram Park' 'Tiong Bahru'
#  'Redhill' 'Queenstown' 'Commonwealth' 'Buona Vista' 'Dover' 'Clementi'
#  'Chinese Garden' 'Lakeside' 'Boon Lay' 'Pioneer' 'Joo Koon' 'Gul Circle'
#  'Tuas Crescent' 'Tuas West Road' 'Tuas Link' 'Expo' 'Changi Airport'
#  'HarbourFront' 'Chinatown' 'Clarke Quay' 'Little India' 'Farrer Park'
#  'Boon Keng' 'Potong Pasir' 'Woodleigh' 'Serangoon' 'Kovan' 'Hougang'
#  'Buangkok' 'Sengkang' 'Punggol' 'Bras Basah' 'Esplanade' 'Promenade'
#  'Nicoll Highway' 'Stadium' 'Mountbatten' 'Dakota' 'MacPherson' 'Tai Seng'
#  'Bartley' 'Lorong Chuan' 'Marymount' 'Caldecott' 'Botanic Gardens'
#  'Farrer Road' 'Holland Village' 'one-north' 'Kent Ridge' 'Haw Par Villa'
#  'Pasir Panjang' 'Labrador Park' 'Telok Blangah' 'Bayfront'
#  'Bukit Panjang' 'Cashew' 'Hillview' 'Beauty World' 'King Albert Park'
#  'Sixth Avenue' 'Tan Kah Kee' 'Stevens' 'Rochor' 'Downtown' 'Telok Ayer'
#  'Fort Canning' 'Bencoolen' 'Jalan Besar' 'Bendemeer' 'Geylang Bahru'
#  'Mattar' 'Ubi' 'Kaki Bukit' 'Bedok North' 'Bedok Reservoir'
#  'Tampines West' 'Tampines East' 'Upper Changi' 'South View' 'Keat Hong'
#  'Teck Whye' 'Phoenix' 'Petir' 'Pending' 'Bangkit' 'Fajar' 'Segar'
#  'Jelapang' 'Senja' 'Ten Mile Junction' 'Compassvale' 'Rumbia' 'Bakau'
#  'Kangkar' 'Ranggung' 'Cheng Lim' 'Farmway' 'Kupang' 'Thanggam' 'Fernvale'
#  'Layar' 'Tongkang' 'Renjong' 'Cove' 'Meridian' 'Coral Edge' 'Riviera'
#  'Kadaloor' 'Oasis' 'Damai' 'Sam Kee' 'Teck Lee' 'Punggol Point'
#  'Samudera' 'Nibong' 'Sumang' 'Soo Teck']

# %%
# Drop unnecessary columns
mrt_data.drop(['mrt_station_chinese','mrt_line_chinese'],axis=1,inplace=True)

# Clean MRT station column to prepare for search value
mrt_data['stn_name_clean']=''
for i in range(len(mrt_data)):
    mrt_stn=mrt_data.iat[i,1] #mrt_station_english
    mrt_line=mrt_data.iat[i,2] #mrt_line_english
    
    # Append with suffix 'LRT' or 'MRT' station
    if mrt_line.endswith('LRT'):
        mrt_data.iat[i,3]=mrt_stn + ' LRT Station'
    else:
        mrt_data.iat[i,3]=mrt_stn + ' MRT Station'

# %%
# Count missing values that require cleaning
print(pd.isna(mrt_data)['mrt_station_english'].sum()) #0

"""
# Clean nan values (but not necessary as no missing values)
mrt_stations_clean=mrt_data.copy()
mrt_stations_clean['stn_name_clean'].replace('',np.nan,inplace=True)
mrt_stations_clean.dropna(subset=['stn_name_clean'],inplace=True)
print('Number of MRT stations cleaned: {}'.format(len(mrt_stations_clean)))
"""
# Out:
# 0
# "\n# Clean nan values (but not necessary as no missing values)\nmrt_stations_clean=mrt_data.copy()\nmrt_stations_clean['stn_name_clean'].replace('',np.nan,inplace=True)\nmrt_stations_clean.dropna(subset=['stn_name_clean'],inplace=True)\nprint('Number of MRT stations cleaned: {}'.format(len(mrt_stations_clean)))\n"

# %%
# Get cleaned list of MRT station names
list_of_mrt=mrt_data.stn_name_clean.unique()
list_of_mrt
# Out:
# array(['Jurong East MRT Station', 'Bukit Batok MRT Station',
#        'Bukit Gombak MRT Station', 'Choa Chu Kang MRT Station',
#        'Yew Tee MRT Station', 'Kranji MRT Station',
#        'Marsiling MRT Station', 'Woodlands MRT Station',
#        'Admiralty MRT Station', 'Sembawang MRT Station',
#        'Yishun MRT Station', 'Khatib MRT Station',
#        'Yio Chu Kang MRT Station', 'Ang Mo Kio MRT Station',
#        'Bishan MRT Station', 'Braddell MRT Station',
#        'Toa Payoh MRT Station', 'Novena MRT Station',
#        'Newton MRT Station', 'Orchard MRT Station',
#        'Somerset MRT Station', 'Dhoby Ghaut MRT Station',
#        'City Hall MRT Station', 'Raffles Place MRT Station',
#        'Marina Bay MRT Station', 'Marina South Pier MRT Station',
#        'Pasir Ris MRT Station', 'Tampines MRT Station',
#        'Simei MRT Station', 'Tanah Merah MRT Station',
#        'Bedok MRT Station', 'Kembangan MRT Station', 'Eunos MRT Station',
#        'Paya Lebar MRT Station', 'Aljunied MRT Station',
#        'Kallang MRT Station', 'Lavender MRT Station', 'Bugis MRT Station',
#        'Tanjong Pagar MRT Station', 'Outram Park MRT Station',
#        'Tiong Bahru MRT Station', 'Redhill MRT Station',
#        'Queenstown MRT Station', 'Commonwealth MRT Station',
#        'Buona Vista MRT Station', 'Dover MRT Station',
#        'Clementi MRT Station', 'Chinese Garden MRT Station',
#        'Lakeside MRT Station', 'Boon Lay MRT Station',
#        'Pioneer MRT Station', 'Joo Koon MRT Station',
#        'Gul Circle MRT Station', 'Tuas Crescent MRT Station',
#        'Tuas West Road MRT Station', 'Tuas Link MRT Station',
#        'Expo MRT Station', 'Changi Airport MRT Station',
#        'HarbourFront MRT Station', 'Chinatown MRT Station',
#        'Clarke Quay MRT Station', 'Little India MRT Station',
#        'Farrer Park MRT Station', 'Boon Keng MRT Station',
#        'Potong Pasir MRT Station', 'Woodleigh MRT Station',
#        'Serangoon MRT Station', 'Kovan MRT Station',
#        'Hougang MRT Station', 'Buangkok MRT Station',
#        'Sengkang MRT Station', 'Punggol MRT Station',
#        'Bras Basah MRT Station', 'Esplanade MRT Station',
#        'Promenade MRT Station', 'Nicoll Highway MRT Station',
#        'Stadium MRT Station', 'Mountbatten MRT Station',
#        'Dakota MRT Station', 'MacPherson MRT Station',
#        'Tai Seng MRT Station', 'Bartley MRT Station',
#        'Lorong Chuan MRT Station', 'Marymount MRT Station',
#        'Caldecott MRT Station', 'Botanic Gardens MRT Station',
#        'Farrer Road MRT Station', 'Holland Village MRT Station',
#        'one-north MRT Station', 'Kent Ridge MRT Station',
#        'Haw Par Villa MRT Station', 'Pasir Panjang MRT Station',
#        'Labrador Park MRT Station', 'Telok Blangah MRT Station',
#        'Bayfront MRT Station', 'Bukit Panjang MRT Station',
#        'Cashew MRT Station', 'Hillview MRT Station',
#        'Beauty World MRT Station', 'King Albert Park MRT Station',
#        'Sixth Avenue MRT Station', 'Tan Kah Kee MRT Station',
#        'Stevens MRT Station', 'Rochor MRT Station',
#        'Downtown MRT Station', 'Telok Ayer MRT Station',
#        'Fort Canning MRT Station', 'Bencoolen MRT Station',
#        'Jalan Besar MRT Station', 'Bendemeer MRT Station',
#        'Geylang Bahru MRT Station', 'Mattar MRT Station',
#        'Ubi MRT Station', 'Kaki Bukit MRT Station',
#        'Bedok North MRT Station', 'Bedok Reservoir MRT Station',
#        'Tampines West MRT Station', 'Tampines East MRT Station',
#        'Upper Changi MRT Station', 'Choa Chu Kang LRT Station',
#        'South View LRT Station', 'Keat Hong LRT Station',
#        'Teck Whye LRT Station', 'Phoenix LRT Station',
#        'Bukit Panjang LRT Station', 'Petir LRT Station',
#        'Pending LRT Station', 'Bangkit LRT Station', 'Fajar LRT Station',
#        'Segar LRT Station', 'Jelapang LRT Station', 'Senja LRT Station',
#        'Ten Mile Junction LRT Station', 'Sengkang LRT Station',
#        'Compassvale LRT Station', 'Rumbia LRT Station',
#        'Bakau LRT Station', 'Kangkar LRT Station', 'Ranggung LRT Station',
#        'Cheng Lim LRT Station', 'Farmway LRT Station',
#        'Kupang LRT Station', 'Thanggam LRT Station',
#        'Fernvale LRT Station', 'Layar LRT Station',
#        'Tongkang LRT Station', 'Renjong LRT Station',
#        'Punggol LRT Station', 'Cove LRT Station', 'Meridian LRT Station',
#        'Coral Edge LRT Station', 'Riviera LRT Station',
#        'Kadaloor LRT Station', 'Oasis LRT Station', 'Damai LRT Station',
#        'Sam Kee LRT Station', 'Teck Lee LRT Station',
#        'Punggol Point LRT Station', 'Samudera LRT Station',
#        'Nibong LRT Station', 'Sumang LRT Station', 'Soo Teck LRT Station'],
#       dtype=object)

# %%
# Find coordinates of MRT stations
for i in range(0, len(list_of_mrt)):
    # Initialize
    query_address = list_of_mrt[i]
    if query_address=='': #Skip if blank
        continue

    query_string = 'https://developers.onemap.sg/commonapi/search?searchVal='+str(query_address)+'&returnGeom=Y&getAddrDetails=Y'
    resp = requests.get(query_string)
    data_mrt=json.loads(resp.content)

    mrt_lat=None
    mrt_long=None

    if data_mrt['found'] != 0:
        mrt_lat=data_mrt["results"][0]["LATITUDE"]
        mrt_long=data_mrt["results"][0]["LONGITUDE"]

        print (str(query_address)+",Lat: "+data_mrt['results'][0]['LATITUDE'] +" Long: "+data_mrt['results'][0]['LONGITUDE'])

    else:
        print ("No Results")

    # Store information in a dataframe
    mrt_location_current = {
        'MRT': list_of_mrt[i],
        'latitude': mrt_lat,
        'longitude': mrt_long}
    mrt_location_current_df=pd.DataFrame.from_dict(mrt_location_current,orient='index').T
    # Append to main dataframe
    mrt_location=mrt_location.append(mrt_location_current_df)
# Out:
# Jurong East MRT Station,Lat: 1.33357652289465 Long: 103.742292350324
# Bukit Batok MRT Station,Lat: 1.34842377665437 Long: 103.749126361849
# Bukit Gombak MRT Station,Lat: 1.35930937732431 Long: 103.751948590322
# Choa Chu Kang MRT Station,Lat: 1.38575650064861 Long: 103.744509334035
# Yew Tee MRT Station,Lat: 1.39753506936297 Long: 103.747405150236
# Kranji MRT Station,Lat: 1.42513172976083 Long: 103.762492227566
# Marsiling MRT Station,Lat: 1.43275722977074 Long: 103.773981720213
# Woodlands MRT Station,Lat: 1.43659643136072 Long: 103.78584424633
# Admiralty MRT Station,Lat: 1.44053338763298 Long: 103.801364534318
# Sembawang MRT Station,Lat: 1.44892733136332 Long: 103.820401560553
# Yishun MRT Station,Lat: 1.42966559741799 Long: 103.83564365509
# Khatib MRT Station,Lat: 1.41789179005502 Long: 103.833171755256
# Yio Chu Kang MRT Station,Lat: 1.3819602145119 Long: 103.844651533361
# Ang Mo Kio MRT Station,Lat: 1.36988737282394 Long: 103.849825701795
# Bishan MRT Station,Lat: 1.35057959895607 Long: 103.84830499183
# Braddell MRT Station,Lat: 1.3404690010277 Long: 103.846799083148
# Toa Payoh MRT Station,Lat: 1.33262928096888 Long: 103.847502198048
# Novena MRT Station,Lat: 1.32044079120154 Long: 103.843825618748
# Newton MRT Station,Lat: 1.31399286264569 Long: 103.837714613091
# Orchard MRT Station,Lat: 1.30489770246908 Long: 103.832525108319
# Somerset MRT Station,Lat: 1.30026416739004 Long: 103.839085753124
# Dhoby Ghaut MRT Station,Lat: 1.29845214658074 Long: 103.846779253533
# Oasis LRT Station,Lat: 1.40228667971123 Long: 103.912727352412
# Damai LRT Station,Lat: 1.40523483636956 Long: 103.908603542566
# Sam Kee LRT Station,Lat: 1.40961268528803 Long: 103.904831550608
# Teck Lee LRT Station,Lat: 1.4127708937463 Long: 103.906577622768
# Punggol Point LRT Station,Lat: 1.41684852031206 Long: 103.906650789313
# Samudera LRT Station,Lat: 1.41590172160383 Long: 103.902156317163
# Nibong LRT Station,Lat: 1.41187040942086 Long: 103.900313788123
# Sumang LRT Station,Lat: 1.40845241943076 Long: 103.898558450395
# Soo Teck LRT Station,Lat: 1.40532331860455 Long: 103.897290522033

# %%
# Visualize output
mrt_location.reset_index(drop=True,inplace=True)
mrt_location.head()
# Out:
#                          MRT          latitude         longitude
# 0    Jurong East MRT Station  1.33357652289465  103.742292350324
# 1    Bukit Batok MRT Station  1.34842377665437  103.749126361849
# 2   Bukit Gombak MRT Station  1.35930937732431  103.751948590322
# 3  Choa Chu Kang MRT Station  1.38575650064861  103.744509334035
# 4        Yew Tee MRT Station  1.39753506936297  103.747405150236

# %%
# Save to CSV for future use
mrt_location.to_csv('mrt_locations.csv',index=False)

# %%
############ Get coordinates of shopping malls ############

# %%
### Get shopping mall locations
# Shopping malls taken from Wikipedia, correct as of Aug 2020
list_of_malls = [
    '100 AM', '313@Somerset', 'Aperia', 'Balestier Hill Shopping Centre', 'Bugis Cube', 'Bugis Junction', 'Bugis+',
    'Capitol Piazza', 'Cathay Cineleisure Orchard', 'City Gate', 'City Square Mall', 'CityLink Mall', 'The Central',
    'Duo', 'Far East Plaza', 'Funan', 'Great World City', 'HDB Hub', 'Holland Village', 'ION Orchard', 'Junction 8',
    'Knightsbridge', 'Liang Court', 'Liat Towers', 'Lucky Plaza', 'Marina Bay Financial Centre Tower 3', 'Marina Bay Link Mall',
    'Marina Bay Sands', 'Marina One', 'Marina Square', 'Midpoint Orchard', 'Millenia Walk', 'Mustafa', 'Ngee Ann City',
    'Orchard Central', 'Orchard Gateway', 'Orchard Plaza', 'Orchard Shopping Centre', 'Palais Renaissance',
    "People's Park Centre", "People's Park Complex", 'Plaza Singapura', 'Pomo', 'Raffles City',
    'Scotts Square', 'Serangoon Plaza', 'Shaw House', 'Sim Lim Square', 'Singapore Shopping Centre', 'Square 2', 'Suntec City',
    'Tanglin Mall', 'Tangs', 'Tanjong Pagar Centre', 'Tekka Centre', 'The Centrepoint', 'The Paragon', 'The Poiz',
    'The Shoppes at Marina Bay Sands', 'The South Beach', 'Thomson Plaza', 'United Square', 'Velocity',
    'Wheelock Place', 'Wisma Atria', 'Zhongshan Mall',
    '112 Katong', 'Bedok Mall', 'Bedok Point', 'Century Square', 'Changi Airport', 'Changi City Point', 'City Plaza',
    'Djitsun Mall Bedok', 'Downtown East', 'East Village', 'Eastpoint Mall', 'Elias Mall', 'Kallang Wave Mall',
    'Katong Square', 'Katong V', 'KINEX', 'Leisure Park Kallang', 'Loyang Point', 'Our Tampines Hub',
    'Parkway Parade', 'Paya Lebar Square', 'PLQ Mall', 'Singapore Post Centre', 'Tampines 1', 'Tampines Mall',
    'The Flow', 'White Sands', '888 Plaza', 'Admiralty Place', 'AMK Hub', 'Beauty World Centre', 'Beauty World Plaza',
    'Broadway Plaza', 'Buangkok Square', 'Bukit Panjang Plaza', 'Bukit Timah Plaza', 'Causeway Point', 'Compass One',
    'Djitsun Mall', 'Fajar Shopping Centre', 'Greenridge Shopping Centre', 'Greenwich V', 'Heartland Mall', 'Hillion Mall',
    'HillV2', 'Hougang 1', 'Hougang Green Shopping Mall', 'Hougang Mall', 'Jubilee Square', 'Junction 10', 'Junction 9',
    'Keat Hong Shopping Centre', 'Limbang Shopping Centre', 'Lot One', 'Marsiling Mall', 'myVillage Serangoon',
    'NEX', 'Northpoint City', 'Oasis Terraces', 'Punggol Plaza', 'Rail Mall', 'Rivervale Mall',
    'Rivervale Plaza', 'Sembawang Shopping Centre', 'Sun Plaza', 'Sunshine Place', 'Teck Whye Shopping Centre', 'The Midtown',
    'The Seletar Mall', 'Upper Serangoon Shopping Centre', 'Waterway Point', 'West Mall', 'Wisteria Mall', 'Woodlands Mart',
    'Yew Tee Point', 'Yew Tee Square', 'Alexandra Retail Centre', 'HarbourFront Centre', 'VivoCity', '321 Clementi',
    'Alexandra Central', 'Anchorpoint', 'Big Box', 'Boon Lay Shopping Centre', 'Fairprice',
    'Gek Poh Shopping Centre', 'Grantral Mall', 'IMM', 'JCube', 'Jem', 'Jurong Point', 'Grandstand', 'Pioneer Mall',
    'Queensway Shopping Centre', 'Rochester Mall', 'Taman Jurong Shopping Centre', 'The Clementi Mall', 'The Star Vista',
    'Tiong Bahru Plaza', 'West Coast Plaza', 'Westgate']

# %%
# Function to fetch coordinates of malls
def get_mall_coord(list_of_shopping_mall):
    # Initialize
    mall_location=pd.DataFrame([],columns=['mall_name', 'searchval','latitude', 'longitude', 'postal_code','road_name'])
    malls_not_found=[]

    for i in range(0, len(list_of_shopping_mall)):
        # Initialize
        query_address = list_of_shopping_mall[i]
        query_string = 'https://developers.onemap.sg/commonapi/search?searchVal='+str(query_address)+'&returnGeom=Y&getAddrDetails=Y'
        resp = requests.get(query_string)
        data_mall=json.loads(resp.content)

        mall_location_current = {
            'mall_name': list_of_shopping_mall[i],
            'searchval':None,
            'latitude': None,
            'longitude': None,
            'postal_code':None,
            'road_name':None}

        # Find number of results found
        if 'found' in data_mall:
            results_num = data_mall['found']
        else:
            results_num = 0

        # Find details if there are results
        if results_num != 0:
            limit=min(10,results_num) # Set limit as 10

            for j in range(limit):
                mall_postal=data_mall['results'][j]['POSTAL'].strip()

                if (mall_postal.isdigit() and len(mall_postal)==6) or i==9:
                    searchval=data_mall["results"][j]["SEARCHVAL"]
                    mall_lat=data_mall["results"][j]["LATITUDE"]
                    mall_long=data_mall["results"][j]["LONGITUDE"]
                    mall_postal=data_mall["results"][j]["POSTAL"]
                    road_name=data_mall['results'][j]['ROAD_NAME']

                    print (str(query_address)+", searchval: "+searchval +" road_name: "+road_name)

                    # Store information in a dataframe
                    mall_location_current = {
                        'mall_name': list_of_shopping_mall[i],
                        'searchval':searchval,
                        'latitude': mall_lat,
                        'longitude': mall_long,
                        'postal_code':mall_postal,
                        'road_name':road_name}
                    break

                else:
                    continue

        else:
            print ("No Results")
            malls_not_found.append(query_address)


        mall_location_current_df=pd.DataFrame.from_dict(mall_location_current,orient='index').T
        # Append to main dataframe
        mall_location=mall_location.append(mall_location_current_df)

    return [mall_location, malls_not_found]

# %%
# Fetch results for list of malls
results=get_mall_coord(list_of_malls)
mall_location=results[0]
malls_not_found=results[1]
mall_location[['mall_name','road_name']]
# Out:
# 100 AM,searchval: 100 AM road_name: TRAS STREET
# 313@Somerset,searchval: UOB 313@SOMERSET road_name: ORCHARD ROAD
# Aperia,searchval: JOSIAH BABIES (APERIA) road_name: KALLANG AVENUE
# Balestier Hill Shopping Centre,searchval: BALESTIER HILL SHOPPING CENTRE road_name: THOMSON ROAD
# Bugis Cube,searchval: BUGIS CUBE road_name: NORTH BRIDGE ROAD
# Bugis Junction,searchval: BUGIS JUNCTION road_name: VICTORIA STREET
# Bugis+,searchval: NEW BUGIS STREET road_name: NEW BUGIS STREET
# Capitol Piazza,searchval: CAPITOL PIAZZA road_name: STAMFORD ROAD
# Cathay Cineleisure Orchard,searchval: UOB CATHAY CINELEISURE ORCHARD road_name: GRANGE ROAD
# City Gate,searchval: CITY GATE road_name: BEACH ROAD
# City Square Mall,searchval: UOB CITY SQUARE MALL AUTOLOBBY road_name: KITCHENER ROAD
# CityLink Mall,searchval: UOB CITYLINK MALL road_name: RAFFLES LINK
# The Central,searchval: THE SUITES AT CENTRAL road_name: DEVONSHIRE ROAD
# Duo,searchval: DUO RESIDENCES road_name: FRASER STREET
# Far East Plaza,searchval: UOB FAR EAST PLAZA road_name: SCOTTS ROAD
# Funan,searchval: GOLDEN VILLAGE (GV FUNAN) road_name: NORTH BRIDGE ROAD
# Great World City,searchval: DBS GREAT WORLD CITY BRANCH road_name: KIM SENG PROMENADE
# HDB Hub,searchval: HDB HUB road_name: LORONG 6 TOA PAYOH
# Holland Village,searchval: ONE HOLLAND VILLAGE road_name: HOLLAND VILLAGE WAY
# ION Orchard,searchval: UOB ION ORCHARD road_name: ORCHARD TURN
# Junction 8,searchval: UOB JUNCTION 8 SHOPPING CENTRE road_name: BISHAN PLACE
# Knightsbridge,searchval: KNIGHTSBRIDGE road_name: ORCHARD ROAD
# Liat Towers,searchval: LIAT TOWERS road_name: ORCHARD ROAD
# Lucky Plaza,searchval: UOB LUCKY PLAZA road_name: ORCHARD ROAD
# Marina Bay Financial Centre Tower 3,searchval: MARINA BAY FINANCIAL CENTRE (TOWER 3) road_name: MARINA BOULEVARD
# Marina Bay Link Mall,searchval: GROUND PLAZA (MARINA BAY LINK MALL) road_name: MARINA BOULEVARD
# Marina Bay Sands,searchval: MARINA BAY SANDS road_name: BAYFRONT AVENUE
# Marina One,searchval: MARINA ONE RESIDENCES road_name: MARINA WAY
# Marina Square,searchval: UOB MARINA SQUARE AUTOLOBBY road_name: RAFFLES BOULEVARD
# Midpoint Orchard,searchval: MIDPOINT ORCHARD road_name: ORCHARD ROAD
# Millenia Walk,searchval: MILLENIA WALK road_name: RAFFLES BOULEVARD
# Mustafa,searchval: MUSTAFA CENTRE road_name: SYED ALWI ROAD
# Ngee Ann City,searchval: UOB NGEE ANN CITY road_name: ORCHARD ROAD
# Orchard Central,searchval: ORCHARD CENTRAL road_name: ORCHARD ROAD
# Orchard Gateway,searchval: ORCHARD GATEWAY @ EMERALD road_name: ORCHARD ROAD
# Orchard Plaza,searchval: UOB ORCHARD PLAZA road_name: ORCHARD ROAD
# Orchard Shopping Centre,searchval: ORCHARD SHOPPING CENTRE road_name: ORCHARD ROAD
# Palais Renaissance,searchval: PALAIS RENAISSANCE road_name: ORCHARD ROAD
# People's Park Centre,searchval: PEOPLE'S PARK CENTRE road_name: UPPER CROSS STREET
# People's Park Complex,searchval: UOB PEOPLE'S PARK COMPLEX FOOD CENTRE road_name: NEW MARKET ROAD
# Plaza Singapura,searchval: UOB PLAZA SINGAPURA road_name: ORCHARD ROAD
# No Results
# Raffles City,searchval: UOB RAFFLES CITY BRANCH road_name: NORTH BRIDGE ROAD
# Scotts Square,searchval: SCOTTS SQUARE road_name: SCOTTS ROAD
# Serangoon Plaza,searchval: SERANGOON PLAZA road_name: SERANGOON ROAD
# Shaw House,searchval: NATIONAL UNIVERSITY OF SINGAPORE (SHAW FOUNDATION ALUMNI HOUSE) road_name: KENT RIDGE DRIVE
# Sim Lim Square,searchval: UOB SIM LIM SQUARE road_name: ROCHOR CANAL ROAD
# Singapore Shopping Centre,searchval: FURAMA CITY CENTRE SINGAPORE / SHOPPING CENTRE road_name: EU TONG SEN STREET
# Square 2,searchval: ASIA SQUARE TOWER 2 road_name: MARINA VIEW
# Suntec City,searchval: SUNTEC CITY MALL road_name: RAFFLES BOULEVARD
# Tanglin Mall,searchval: UOB TANGLIN MALL road_name: TANGLIN ROAD
# Tangs,searchval: DBS TANGS ORCHARD road_name: ORCHARD ROAD
# Tanjong Pagar Centre,searchval: TANJONG PAGAR CENTRE road_name: WALLICH STREET
# Tekka Centre,searchval: ZHUJIAO CENTRE (TEKKA MARKET) road_name: BUFFALO ROAD
# The Centrepoint,searchval: THE CENTREPOINT road_name: ORCHARD ROAD
# The Paragon,searchval: UOB THE PARAGON road_name: ORCHARD ROAD
# The Poiz,searchval: THE POIZ RESIDENCES road_name: MEYAPPA CHETTIAR ROAD
# The Shoppes at Marina Bay Sands,searchval: THE SHOPPES AT MARINA BAY SANDS road_name: BAYFRONT AVENUE
# The South Beach,searchval: THE SOUTH BEACH road_name: BEACH ROAD
# Thomson Plaza,searchval: THOMSON PLAZA road_name: UPPER THOMSON ROAD
# United Square,searchval: UOB UNITED SQUARE AUTOLOBBY road_name: THOMSON ROAD
# Velocity,searchval: VELOCITY @ NOVENA SQUARE road_name: THOMSON ROAD
# Wheelock Place,searchval: WHEELOCK PLACE road_name: ORCHARD ROAD
# Wisma Atria,searchval: WISMA ATRIA road_name: ORCHARD ROAD
# Zhongshan Mall,searchval: ZHONGSHAN MALL road_name: AH HOOD ROAD
# 112 Katong,searchval: DBS 112 KATONG road_name: EAST COAST ROAD
# Bedok Mall,searchval: UOB BEDOK MALL road_name: NEW UPPER CHANGI ROAD
# Bedok Point,searchval: BEDOK POINT road_name: NEW UPPER CHANGI ROAD
# Century Square,searchval: FILMGARDE AT CENTURY SQUARE road_name: TAMPINES CENTRAL 5
# Changi Airport,searchval: JEWEL CHANGI AIRPORT road_name: AIRPORT BOULEVARD
# Changi City Point,searchval: CHANGI CITY POINT road_name: CHANGI BUSINESS PARK CENTRAL 1
# City Plaza,searchval: UOB CITY PLAZA BRANCH road_name: GEYLANG ROAD
# Djitsun Mall Bedok,searchval: DJITSUN MALL BEDOK road_name: BEDOK NORTH STREET 1
# Downtown East,searchval: COSTA SANDS RESORT (DOWNTOWN EAST) road_name: PASIR RIS CLOSE
# East Village,searchval: EAST VILLAGE road_name: UPPER CHANGI ROAD
# Eastpoint Mall,searchval: UOB EASTPOINT MALL AUTO LOBBY road_name: SIMEI STREET 6
# Elias Mall,searchval: ELIAS MALL road_name: ELIAS ROAD
# Kallang Wave Mall,searchval: KALLANG WAVE MALL road_name: STADIUM PLACE
# Katong Square,searchval: KATONG SQUARE road_name: EAST COAST ROAD
# Katong V,searchval: KATONG V road_name: EAST COAST ROAD
# KINEX,searchval: KINEX road_name: TANJONG KATONG ROAD
# Leisure Park Kallang,searchval: UOB KALLANG LEISURE PARK road_name: STADIUM WALK
# Loyang Point,searchval: LOYANG POINT road_name: PASIR RIS STREET 21
# Our Tampines Hub,searchval: OUR TAMPINES HUB HAWKER CENTRE road_name: TAMPINES WALK
# Parkway Parade,searchval: UOB PARKWAY PARADE BRANCH road_name: MARINE PARADE ROAD
# Paya Lebar Square,searchval: UOB PAYA LEBAR SQUARE road_name: PAYA LEBAR ROAD
# PLQ Mall,searchval: PLQ MALL road_name: PAYA LEBAR ROAD
# Singapore Post Centre,searchval: SINGPOST REGIONAL ECOMMERCE LOGISTICS HUB road_name: GREENWICH DRIVE
# Tampines 1,searchval: TAMPINES PLAZA 1 road_name: TAMPINES CENTRAL 1
# Tampines Mall,searchval: UOB TAMPINES MALL AUTOLOBBY road_name: TAMPINES CENTRAL 5
# The Flow,searchval: THE FLOW MALL road_name: EAST COAST ROAD
# White Sands,searchval: WHITE SANDS PRIMARY SCHOOL road_name: PASIR RIS STREET 11
# 888 Plaza,searchval: UOB WOODLANDS 888 PLAZA road_name: WOODLANDS DRIVE 50
# Admiralty Place,searchval: ADMIRALTY PLACE road_name: WOODLANDS AVENUE 6
# AMK Hub,searchval: OCBC AMK HUB road_name: ANG MO KIO AVENUE 3
# Beauty World Centre,searchval: BEAUTY WORLD CENTRE road_name: UPPER BUKIT TIMAH ROAD
# Beauty World Plaza,searchval: BEAUTY WORLD PLAZA road_name: UPPER BUKIT TIMAH ROAD
# Broadway Plaza,searchval: BROADWAY PLAZA road_name: ANG MO KIO AVENUE 6
# Buangkok Square,searchval: BUANGKOK SQUARE road_name: BUANGKOK LINK
# Bukit Panjang Plaza,searchval: OCBC BUKIT PANJANG PLAZA road_name: JELEBU ROAD
# Bukit Timah Plaza,searchval: UOB BUKIT TIMAH PLAZA road_name: JALAN ANAK BUKIT
# Causeway Point,searchval: UOB CAUSEWAY POINT road_name: WOODLANDS SQUARE
# Compass One,searchval: OCBC COMPASS ONE BRANCH road_name: SENGKANG SQUARE
# Djitsun Mall,searchval: DJITSUN MALL BEDOK road_name: BEDOK NORTH STREET 1
# Fajar Shopping Centre,searchval: FAJAR SHOPPING CENTRE road_name: FAJAR ROAD
# Greenridge Shopping Centre,searchval: UOB GREENRIDGE SHOPPING CENTRE road_name: JELAPANG ROAD
# Greenwich V,searchval: GREENWICH V road_name: SELETAR ROAD
# Heartland Mall,searchval: UOB HEARTLAND MALL road_name: HOUGANG STREET 21
# Hillion Mall,searchval: OCBC HILLION MALL - FAIRPRICE road_name: PETIR ROAD
# HillV2,searchval: HILLV2 road_name: HILLVIEW RISE
# Hougang 1,searchval: UOB HOUGANG AVENUE 1 road_name: HOUGANG AVENUE 1
# Hougang Green Shopping Mall,searchval: UOB HOUGANG GREEN SHOPPING MALL road_name: HOUGANG STREET 51
# Hougang Mall,searchval: UOB HOUGANG MALL road_name: HOUGANG AVENUE 10
# No Results
# Junction 10,searchval: JUNCTION 10 road_name: WOODLANDS ROAD
# Junction 9,searchval: JUNCTION NINE road_name: YISHUN AVENUE 9
# Keat Hong Shopping Centre,searchval: KEAT HONG SHOPPING CENTRE road_name: CHOA CHU KANG AVENUE 1
# Limbang Shopping Centre,searchval: LIMBANG SHOPPING CENTRE road_name: CHOA CHU KANG STREET 51
# Lot One,searchval: SHAW THEATRES LOT ONE road_name: CHOA CHU KANG AVENUE 4
# Marsiling Mall,searchval: MARSILING MALL HAWKER CENTRE road_name: WOODLANDS STREET 12
# myVillage Serangoon,searchval: MYVILLAGE AT SERANGOON GARDEN road_name: MAJU AVENUE
# NEX,searchval: NEX road_name: SERANGOON CENTRAL
# Northpoint City,searchval: NORTHPOINT CITY road_name: YISHUN AVENUE 2
# Oasis Terraces,searchval: OASIS TERRACES road_name: PUNGGOL DRIVE
# Punggol Plaza,searchval: UOB PUNGGOL PLAZA road_name: PUNGGOL FIELD
# Rail Mall,searchval: THE RAIL MALL road_name: UPPER BUKIT TIMAH ROAD
# Rivervale Mall,searchval: UOB RIVERVALE MALL road_name: RIVERVALE CRESCENT
# Rivervale Plaza,searchval: UOB RIVERVALE PLAZA road_name: RIVERVALE DRIVE
# Sembawang Shopping Centre,searchval: UOB SEMBAWANG SHOPPING CENTRE road_name: SEMBAWANG ROAD
# Sun Plaza,searchval: SUN PLAZA road_name: SEMBAWANG DRIVE
# Sunshine Place,searchval: UOB SUNSHINE PLACE road_name: CHOA CHU KANG AVENUE 3
# Teck Whye Shopping Centre,searchval: TECK WHYE SHOPPING CENTRE road_name: TECK WHYE LANE
# The Midtown,searchval: THE MIDTOWN road_name: UPPER SERANGOON ROAD
# The Seletar Mall,searchval: UOB THE SELETAR MALL road_name: SENGKANG WEST AVENUE
# Upper Serangoon Shopping Centre,searchval: UPPER SERANGOON SHOPPING CENTRE road_name: UPPER SERANGOON ROAD
# Waterway Point,searchval: DBS WATERWAY POINT BRANCH road_name: PUNGGOL CENTRAL
# West Mall,searchval: WEST MALL road_name: BUKIT BATOK CENTRAL LINK
# Wisteria Mall,searchval: WISTERIA MALL road_name: YISHUN RING ROAD
# Woodlands Mart,searchval: WOODLANDS MART road_name: WOODLANDS AVENUE 6
# Yew Tee Point,searchval: UOB YEW TEE POINT road_name: CHOA CHU KANG NORTH 6
# Yew Tee Square,searchval: YEW TEE SQUARE road_name: CHOA CHU KANG STREET 62
# Alexandra Retail Centre,searchval: UOB ALEXANDRA RETAIL CENTRE road_name: ALEXANDRA ROAD
# HarbourFront Centre,searchval: UOB HARBOURFRONT CENTRE AUTOLOBBY road_name: MARITIME SQUARE
# VivoCity,searchval: VIVOCITY STATION (S1) road_name: TELOK BLANGAH ROAD
# 321 Clementi,searchval: 321 CLEMENTI road_name: CLEMENTI AVENUE 3
# Alexandra Central,searchval: ALEXANDRA CENTRAL road_name: ALEXANDRA ROAD
# Anchorpoint,searchval: ANCHORPOINT SHOPPING CENTRE road_name: ALEXANDRA ROAD
# Big Box,searchval: POSSO PRESCHOOL @ BIG BOX PTE. LTD. road_name: VENTURE AVENUE
# Boon Lay Shopping Centre,searchval: OCBC BOON LAY SHOPPING CENTRE FAIRPRICE road_name: BOON LAY PLACE
# Fairprice,searchval: FAIRPRICE HUB road_name: JOO KOON CIRCLE
# Gek Poh Shopping Centre,searchval: GEK POH SHOPPING CENTRE road_name: JURONG WEST STREET 75
# Grantral Mall,searchval: GRANTRAL MALL @ CLEMENTI road_name: COMMONWEALTH AVENUE WEST
# IMM,searchval: UOB IMM BUILDING AUTOLOBBY road_name: JURONG EAST STREET 21
# JCube,searchval: SHAW THEATRES JCUBE road_name: JURONG EAST CENTRAL 1
# Jem,searchval: UOB JEM BRANCH road_name: JURONG GATEWAY ROAD
# Jurong Point,searchval: OCBC JURONG POINT SHOPPING CENTRE - JURONG POINT BRANCH road_name: JURONG WEST CENTRAL 2
# Grandstand,searchval: THE GRANDSTAND road_name: TURF CLUB ROAD
# Pioneer Mall,searchval: UOB PIONEER MALL road_name: JURONG WEST STREET 61
# Queensway Shopping Centre,searchval: QUEENSWAY SHOPPING CENTRE road_name: QUEENSWAY
# Rochester Mall,searchval: ROCHESTER MALL road_name: ROCHESTER DRIVE
# Taman Jurong Shopping Centre,searchval: UOB TAMAN JURONG SHOPPING CENTRE road_name: YUNG SHENG ROAD
# The Clementi Mall,searchval: THE CLEMENTI MALL road_name: COMMONWEALTH AVENUE WEST
# The Star Vista,searchval: THE STAR VISTA road_name: VISTA EXCHANGE GREEN
# Tiong Bahru Plaza,searchval: TIONG BAHRU PLAZA road_name: TIONG BAHRU ROAD
# West Coast Plaza,searchval: WEST COAST PLAZA road_name: WEST COAST ROAD
# Westgate,searchval: WESTGATE TOWER road_name: GATEWAY DRIVE
#                              mall_name                       road_name
# 0                               100 AM                     TRAS STREET
# 0                         313@Somerset                    ORCHARD ROAD
# 0                               Aperia                  KALLANG AVENUE
# 0       Balestier Hill Shopping Centre                    THOMSON ROAD
# 0                           Bugis Cube               NORTH BRIDGE ROAD
# 0                       Bugis Junction                 VICTORIA STREET
# 0                               Bugis+                NEW BUGIS STREET
# 0                       Capitol Piazza                   STAMFORD ROAD
# 0           Cathay Cineleisure Orchard                     GRANGE ROAD
# 0                            City Gate                      BEACH ROAD
# 0                     City Square Mall                  KITCHENER ROAD
# 0                        CityLink Mall                    RAFFLES LINK
# 0                        Downtown East                 PASIR RIS CLOSE
# 0                         East Village               UPPER CHANGI ROAD
# 0                       Eastpoint Mall                  SIMEI STREET 6
# 0                           Elias Mall                      ELIAS ROAD
# 0                    Kallang Wave Mall                   STADIUM PLACE
# 0                        Katong Square                 EAST COAST ROAD
# 0                             Katong V                 EAST COAST ROAD
# 0                                KINEX             TANJONG KATONG ROAD
# 0                 Leisure Park Kallang                    STADIUM WALK
# 0                         Loyang Point             PASIR RIS STREET 21
# 0                     Our Tampines Hub                   TAMPINES WALK
# 0                       Parkway Parade              MARINE PARADE ROAD
# 0                    Paya Lebar Square                 PAYA LEBAR ROAD
# 0                             PLQ Mall                 PAYA LEBAR ROAD
# 0                Singapore Post Centre                 GREENWICH DRIVE
# 0                           Tampines 1              TAMPINES CENTRAL 1
# 0                        Tampines Mall              TAMPINES CENTRAL 5
# 0                             The Flow                 EAST COAST ROAD
# 0                          White Sands             PASIR RIS STREET 11
# 0                            888 Plaza              WOODLANDS DRIVE 50
# 0                      Admiralty Place              WOODLANDS AVENUE 6
# 0                              AMK Hub             ANG MO KIO AVENUE 3
# 0                  Beauty World Centre          UPPER BUKIT TIMAH ROAD
# 0                   Beauty World Plaza          UPPER BUKIT TIMAH ROAD
# 0                       Broadway Plaza             ANG MO KIO AVENUE 6
# 0                      Buangkok Square                   BUANGKOK LINK
# 0                  Bukit Panjang Plaza                     JELEBU ROAD
# 0                    Bukit Timah Plaza                JALAN ANAK BUKIT
# 0                       Causeway Point                WOODLANDS SQUARE
# 0                          Compass One                 SENGKANG SQUARE
# 0                         Djitsun Mall            BEDOK NORTH STREET 1
# 0                Fajar Shopping Centre                      FAJAR ROAD
# 0           Greenridge Shopping Centre                   JELAPANG ROAD
# 0                          Greenwich V                    SELETAR ROAD
# 0                       Heartland Mall               HOUGANG STREET 21
# 0                         Hillion Mall                      PETIR ROAD
# 0                               HillV2                   HILLVIEW RISE
# 0                            Hougang 1                HOUGANG AVENUE 1
# 0          Hougang Green Shopping Mall               HOUGANG STREET 51
# 0                         Hougang Mall               HOUGANG AVENUE 10
# 0                       Jubilee Square                            None
# 0                          Junction 10                  WOODLANDS ROAD
# 0                           Junction 9                 YISHUN AVENUE 9
# 0            Keat Hong Shopping Centre          CHOA CHU KANG AVENUE 1
# 0              Limbang Shopping Centre         CHOA CHU KANG STREET 51
# 0                              Lot One          CHOA CHU KANG AVENUE 4
# 0                       Marsiling Mall             WOODLANDS STREET 12
# 0                  myVillage Serangoon                     MAJU AVENUE
# 0                                  NEX               SERANGOON CENTRAL
# 0                      Northpoint City                 YISHUN AVENUE 2
# 0                       Oasis Terraces                   PUNGGOL DRIVE
# 0                        Punggol Plaza                   PUNGGOL FIELD
# 0                            Rail Mall          UPPER BUKIT TIMAH ROAD
# 0                       Rivervale Mall              RIVERVALE CRESCENT
# 0                      Rivervale Plaza                 RIVERVALE DRIVE
# 0            Sembawang Shopping Centre                  SEMBAWANG ROAD
# 0                            Sun Plaza                 SEMBAWANG DRIVE
# 0                       Sunshine Place          CHOA CHU KANG AVENUE 3
# 0            Teck Whye Shopping Centre                  TECK WHYE LANE
# 0                          The Midtown            UPPER SERANGOON ROAD
# 0                     The Seletar Mall            SENGKANG WEST AVENUE
# 0      Upper Serangoon Shopping Centre            UPPER SERANGOON ROAD
# 0                       Waterway Point                 PUNGGOL CENTRAL
# 0                            West Mall        BUKIT BATOK CENTRAL LINK
# 0                        Wisteria Mall                YISHUN RING ROAD
# 0                       Woodlands Mart              WOODLANDS AVENUE 6
# 0                        Yew Tee Point           CHOA CHU KANG NORTH 6
# 0                       Yew Tee Square         CHOA CHU KANG STREET 62
# 0              Alexandra Retail Centre                  ALEXANDRA ROAD
# 0                  HarbourFront Centre                 MARITIME SQUARE
# 0                             VivoCity              TELOK BLANGAH ROAD
# 0                         321 Clementi               CLEMENTI AVENUE 3
# 0                    Alexandra Central                  ALEXANDRA ROAD
# 0                          Anchorpoint                  ALEXANDRA ROAD
# 0                              Big Box                  VENTURE AVENUE
# 0             Boon Lay Shopping Centre                  BOON LAY PLACE
# 0                            Fairprice                 JOO KOON CIRCLE
# 0              Gek Poh Shopping Centre           JURONG WEST STREET 75
# 0                        Grantral Mall        COMMONWEALTH AVENUE WEST
# 0                                  IMM           JURONG EAST STREET 21
# 0                                JCube           JURONG EAST CENTRAL 1
# 0                                  Jem             JURONG GATEWAY ROAD
# 0                         Jurong Point           JURONG WEST CENTRAL 2
# 0                           Grandstand                  TURF CLUB ROAD
# 0                         Pioneer Mall           JURONG WEST STREET 61
# 0            Queensway Shopping Centre                       QUEENSWAY
# 0                       Rochester Mall                 ROCHESTER DRIVE
# 0         Taman Jurong Shopping Centre                 YUNG SHENG ROAD
# 0                    The Clementi Mall        COMMONWEALTH AVENUE WEST
# 0                       The Star Vista            VISTA EXCHANGE GREEN
# 0                    Tiong Bahru Plaza                TIONG BAHRU ROAD
# 0                     West Coast Plaza                 WEST COAST ROAD
# 0                             Westgate                   GATEWAY DRIVE

# %%
# Hardcode for malls not found and get coordinates
print(malls_not_found)
# Out:
# ['Pomo', 'Jubilee Square']

# %%
# Re-fetch results for Pomo and Jubilee Square
malls_round2=['GR.ID','569814'] # Change search values for pomo and jubliee square to these
results_round2=get_mall_coord(malls_round2)
mall_location_round2=results_round2[0]
malls_not_found_round2=results_round2[1]

# See results
malls_not_found_round2
mall_location_round2
# Out:
# GR.ID,searchval: GR.ID road_name: SELEGIE ROAD
# 569814,searchval: 61 ANG MO KIO AVENUE 8 SINGAPORE 569814 road_name: ANG MO KIO AVENUE 8
#   mall_name                                searchval          latitude  \
# 0     GR.ID                                    GR.ID  1.30004685562708
# 0    569814  61 ANG MO KIO AVENUE 8 SINGAPORE 569814  1.37178551879641
#
#           longitude postal_code            road_name
# 0  103.849246371869      188306         SELEGIE ROAD
# 0  103.847775723803      569814  ANG MO KIO AVENUE 8

# %%
# Correct mall name for Jubilee Square
mall_location_round2.loc[mall_location_round2['mall_name']=='569814',['mall_name']]='Jubilee Square'

# Append to main dataframe
mall_location=mall_location.append(mall_location_round2)
mall_location.sort_values(['mall_name'],inplace=True)
mall_location.dropna(inplace=True)

# %%
# Save mall locations to CSV
mall_location.to_csv('mall_location.csv',index=False)
